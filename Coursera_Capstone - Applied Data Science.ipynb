# %% [markdown]
# # CAPSTONE PROJECT NOTEBOOK

# %% [markdown]
# This notebook will be used to complete the final project for the IBM Data Science 9-Course Program

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Hello Capstone Project Course
